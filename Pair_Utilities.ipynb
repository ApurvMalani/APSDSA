// %%
// Pairs of  Utility  Libraries ..

// #include<bits/stdc++.h>
// using namespace std;

// int main()
// {
//     pair <int , int> my_pair(21 , 22);

//     cout << "the first  pair num is :- " << my_pair.first <<  endl;
//     cout << "the  second pair num is :- "<< my_pair.second << endl;

//   my_pair.first = 23;
//   my_pair.second = 24;

//   cout << "the first pair num  is  :- "<<my_pair.first << endl;
//   cout << "the  second pair num is :- "<<my_pair.second << endl;
//     return 0;
// }
#include <bits/stdc++.h>
using namespace std;

void exampleofpair()
{
    pair<int, int> p1 = make_pair(80, 90);
    cout << p1.first << " and " << p1.second << endl;

    pair<int, pair<int, int>> p2 = make_pair(1, make_pair(2, 3));
    cout << p2.first << " " << p2.second.first << " " << p2.second.second << endl;

    pair<int, int> array[] = {{50, 60}, {70, 80}, {90, 100}};
    cout << array[2].second << endl;
}

int main()
{
    exampleofpair();
    return 0;
}
